# %%
import pandas as pd

# %%
vaccine_data = pd.read_csv("vaccine_data.csv")
hospital_data = pd.read_csv("hospital_utilization.csv")
flight_data = pd.read_csv("flight_data.csv")

dataPartial = pd.merge(vaccine_data, hospital_data, on="Date")
dataComplete = pd.merge(dataPartial, flight_data, on="Date")
dataComplete
# Out:
#           Date  Total Doses Administered  Daily Increase  \
# 0    2/13/2022                 548792878          144101
# 1    2/12/2022                 548648777          327557
# 2    2/11/2022                 548321220          582026
# 3    2/10/2022                 547739194          473174
# 4     2/9/2022                 547266020          478132
# ..         ...                       ...             ...
# 748  1/27/2020                         0               0
# 749  1/26/2020                         0               0
# 750  1/25/2020                         0               0
# 751  1/24/2020                         0               0
# 752  1/23/2020                         0               0
#
#      Current Hospitalized COVID-19 Patients  Number of Flights
# 0                                  82055.86             162754
# 1                                  85521.43             182400
# 2                                  89003.00             199407
# ...
